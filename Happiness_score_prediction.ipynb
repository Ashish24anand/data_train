# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('dataset.csv')

# %%
df
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# Country and Happiness Rank have a unique value for every index so there is no relationship between Happiness Score and their features

# %%
df=pd.concat([df,pd.get_dummies(df.Region, drop_first=False)],axis=1)

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  ...  Sub-Saharan Africa  Western Europe
# count      158.000000       158.000000  ...          158.000000      158.000000
# mean        79.493671         5.375734  ...            0.253165        0.132911
# std         45.754363         1.145010  ...            0.436207        0.340558
# min          1.000000         2.839000  ...            0.000000        0.000000
# 25%         40.250000         4.526000  ...            0.000000        0.000000
# 50%         79.500000         5.232500  ...            0.000000        0.000000
# 75%        118.750000         6.243750  ...            0.750000        0.000000
# max        158.000000         7.587000  ...            1.000000        1.000000
#
# [8 rows x 20 columns]

# %% [markdown]
# ***Normalization***

# %%
import scipy.stats as stat
import pylab

# %%
cat=[]
num=[]
for i in df.columns:
  if df[i].nunique()<10:
    cat.append(i)
  else:
    num.append(i)

# %%
df1=pd.DataFrame()
for i in df[num].iloc[:,3:].columns:

    plt.figure(figsize=(15,9))
    plt.subplot(2,5,1)
    plt.hist(df[i])
    plt.xlabel(i)
    plt.subplot(2,5,2)
    stat.probplot(df[i],dist='norm',plot=pylab)
    plt.xlabel(i)
    

    df1[i+'log']=np.log(df[i]+0.00001)
    
    plt.subplot(2,5,3)
    plt.hist(df1[i+'log'])
    plt.xlabel(i+'log')
    plt.subplot(2,5,4)
    stat.probplot(df1[i+'log'],dist='norm',plot=pylab)
    plt.xlabel(i+'log')
    
    df1[i+'Boxcox'],para=stat.boxcox(df[i]+1)
    
    
    plt.subplot(2,5,5)
    plt.hist(df1[i+'Boxcox'])
    plt.xlabel(i+'Boxcox')
    plt.subplot(2,5,6)
    stat.probplot(df1[i+'Boxcox'],dist='norm',plot=pylab)
    plt.xlabel(i+'Boxcox')


    df1[i+'sqrt']=df[i]**(1/2)

    
    plt.subplot(2,5,7)
    plt.hist(df1[i+'sqrt'])
    plt.xlabel(i+'sqrt')
    plt.subplot(2,5,8)
    stat.probplot(df1[i+'sqrt'],dist='norm',plot=pylab)
    plt.xlabel(i+'sqrt')
    
    df1[i+'exponential']=df[i]**(1/1.2)

    
    plt.subplot(2,5,9)
    plt.hist(df1[i+'exponential'])
    plt.xlabel(i+'exponential')
    plt.subplot(2,5,10)
    stat.probplot(df1[i+'exponential'],dist='norm',plot=pylab)
    plt.xlabel(i+'exponential')
    
  ##  df1[i+'reciprocal']=1/(1+df[i])

    plt.show()

# %% [markdown]
# ***Normilization action needed***
#
# Happiness Score- No need to change.
# Standard Error- Boxcox
# Economy (GDP per Capita)- No need to change.
# Family- Boxcox
# Health (Life Expectancy)- Boxcox
# Freedom- No need to change.
# Trust (Government Corruption)- sqrt
# Generosity-Boxcox
# Dystopia Residual-Boxcox

# %%
df.skew()
# Out:
# Happiness Rank                     0.000418
# Happiness Score                    0.097769
# Standard Error                     1.983439
# Economy (GDP per Capita)          -0.317575
# Family                            -1.006893
# Health (Life Expectancy)          -0.705328
# Freedom                           -0.413462
# Trust (Government Corruption)      1.385463
# Generosity                         1.001961
# Dystopia Residual                 -0.238911
# Australia and New Zealand          8.802321
# Central and Eastern Europe         1.650669
# Eastern Asia                       4.881004
# Latin America and Caribbean        2.104155
# Middle East and Northern Africa    2.267677
# North America                      8.802321
# Southeastern Asia                  3.859823
# Southern Asia                      4.471763
# Sub-Saharan Africa                 1.146245
# Western Europe                     2.183443
# dtype: float64

# %%
df['Standard Error']=df1['Standard ErrorBoxcox']         
df.Family=df1.FamilyBoxcox    
df['Health (Life Expectancy)']=df1['Health (Life Expectancy)Boxcox']    
df['Trust (Government Corruption)']=df1['Trust (Government Corruption)sqrt']  
df.Generosity=df1.GenerosityBoxcox  
df['Dystopia Residual']=df1['Dystopia ResidualBoxcox']

# %%
df.skew()
# Out:
# Happiness Rank                     0.000418
# Happiness Score                    0.097769
# Standard Error                    -0.020092
# Economy (GDP per Capita)          -0.317575
# Family                            -0.169651
# Health (Life Expectancy)          -0.183181
# Freedom                           -0.413462
# Trust (Government Corruption)      0.507663
# Generosity                         0.013320
# Dystopia Residual                  0.022925
# Australia and New Zealand          8.802321
# Central and Eastern Europe         1.650669
# Eastern Asia                       4.881004
# Latin America and Caribbean        2.104155
# Middle East and Northern Africa    2.267677
# North America                      8.802321
# Southeastern Asia                  3.859823
# Southern Asia                      4.471763
# Sub-Saharan Africa                 1.146245
# Western Europe                     2.183443
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,  10))
df.boxplot(ax=ax)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.iloc[:,3:].corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# Happiness score is corelated with many variable for more clarification we will use scatter plot

# %%
x=df.iloc[:,4:]
y=df.iloc[:,3]

# %%
cat=[]
num=[]
for i in x.columns:
  if x[i].nunique()<10:
    cat.append(i)
  else:
    num.append(i)

# %%
for i in x[num].columns:
  sns.regplot(x=i,y='Happiness Score',data=df)
  plt.show()

# %% [markdown]
# Almost all the Numracial feature are correlated with happiness score

# %%
sns.pairplot(df[num])

# %% [markdown]
# From Pair plot it is clear that feature are interrelated to each other or multicolinarity exists

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from sklearn.preprocessing import StandardScaler as SS
x_scaler=SS().fit_transform(x)
vif=pd.DataFrame()
vif['vif']=[VIF(x_scaler,i) for i in range(x_scaler.shape[1])]
vif['feature']=x.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/stats/outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vif.sort_values(by='vif')
# Out:
#          vif                          feature
# 7   1.289775                Dystopia Residual
# 0   1.588148                   Standard Error
# 5   1.609041    Trust (Government Corruption)
# 6   1.793304                       Generosity
# 4   2.236441                          Freedom
# 2   2.734461                           Family
# 1   5.411274         Economy (GDP per Capita)
# 3   7.156856         Health (Life Expectancy)
# 15       inf                    Southern Asia
# 14       inf                Southeastern Asia
# 13       inf                    North America
# 12       inf  Middle East and Northern Africa
# 8        inf        Australia and New Zealand
# 10       inf                     Eastern Asia
# 9        inf       Central and Eastern Europe
# 16       inf               Sub-Saharan Africa
# 11       inf      Latin America and Caribbean
# 17       inf                   Western Europe

# %% [markdown]
# Economy and Health are highly correlated

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
fvalue_selector = SelectKBest(f_classif, k=2)

x_new = fvalue_selector.fit(x, y)
pd.DataFrame([x.columns,x_new.scores_]).T.sort_values(by=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
#                                   0            1
# 12  Middle East and Northern Africa     0.217543
# 9        Central and Eastern Europe     0.297144
# 4                           Freedom     0.904457
# 2                            Family      5.57401
# 6                        Generosity      6.44062
# 0                    Standard Error      8.15927
# 7                 Dystopia Residual      12.7746
# 1          Economy (GDP per Capita)      62.3956
# 3          Health (Life Expectancy)      103.619
# 5     Trust (Government Corruption)  2.91998e+07
# 15                    Southern Asia          inf
# 14                Southeastern Asia          inf
# 13                    North America          inf
# 8         Australia and New Zealand          inf
# 10                     Eastern Asia          inf
# 16               Sub-Saharan Africa          inf
# 11      Latin America and Caribbean          inf
# 17                   Western Europe          inf

# %% [markdown]
# All the variables have **VIF** less than 5 and Economy (GDP per Capita is highly related to Happiness Score so There is no need to drop any column.
#
#
# Secondly, as there are only 158 rows in the dataset it is best to use  Leave One Out cross validation

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
cv = LeaveOneOut()


model = LinearRegression()


scores = cross_val_score(model, x, y, scoring='neg_root_mean_squared_error',
                         cv=cv, n_jobs=-1)

scores.mean()
# Out:
# -0.0673143076075978

# %%
from sklearn.svm import LinearSVR
model1 = LinearSVR()


scores = cross_val_score(model1, x, y, scoring='neg_root_mean_squared_error',
                         cv=cv, n_jobs=-1)

scores.mean()
# Out:
# -0.06801937294347046

# %%
from sklearn.linear_model import Ridge

model2=Ridge()

scores = cross_val_score(model2, x, y, scoring='neg_root_mean_squared_error',
                         cv=cv, n_jobs=-1)

scores.mean()
# Out:
# -0.09555944888353525

# %%
from sklearn.linear_model import Lasso

model3=Lasso()

scores = cross_val_score(model3, x, y, scoring='neg_root_mean_squared_error',
                         cv=cv, n_jobs=-1)

scores.mean()
# Out:
# -0.8434516392612212

# %%
from sklearn.linear_model import HuberRegressor as HR

model4=HR()

scores = cross_val_score(model4, x, y, scoring='neg_root_mean_squared_error',
                         cv=cv, n_jobs=-1)

scores.mean()
# Out:
# -0.061922305001783286

# %% [markdown]
# Let's select top 2 regressor and do ***Hyperparameter tuning***.
#
#
# 1-HuberRegressor
# 2-Linear SVR

# %%
hr_params={'epsilon':[1,1.15,1.3],
           'max_iter':[50,100,125],
           'alpha':[1e-07,1e-06,1e-05]
           }

from sklearn.model_selection import GridSearchCV as GSCV


reg_hr=GSCV(HR(),hr_params,cv=LeaveOneOut(),scoring='neg_root_mean_squared_error')

hr_model=reg_hr.fit(x,y)

# %%
hr_model.best_estimator_
# Out:
# HuberRegressor(alpha=1e-06, epsilon=1.15)

# %%
hr_model.best_score_
# Out:
# -0.06142851295644795

# %%
lsvr_params={'C':[1.45,1.6,1.75],
             
             'max_iter':[25000,27000,29000]
           }


reg_lsvr=GSCV(LinearSVR(),lsvr_params,cv=LeaveOneOut(),scoring='neg_root_mean_squared_error')


lsvr_model=reg_lsvr.fit(x,y)

# %%
lsvr_model.best_estimator_
# Out:
# LinearSVR(C=1.6, max_iter=27000)

# %%
lsvr_model.best_score_
# Out:
# -0.06250361004973698

# %%
sec_model=LinearSVR(C=1.6, max_iter=27000)

# %% [markdown]
# HuberRegressor is the best Rergessor

# %%
best_model= HR(alpha=1e-06, epsilon=1.15)

# %%
from sklearn.model_selection import train_test_split as TTS
x_train,x_test,y_train,y_test=TTS(x,y,test_size=0.1,random_state=102)

# %%
best_reg=best_model.fit(x_train,y_train)
y_pred=best_reg.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
plt.scatter(x=y_test.index,y=y_test,cmap='red')
plt.scatter(x=y_test.index,y=y_pred,cmap='blue')

# %%
scores = cross_val_score(best_model, x, y, scoring='neg_root_mean_squared_error',
                         cv=10, n_jobs=-1)

scores.mean()
# Out:
# -0.09011581069616827

# %%
scores
# Out:
# array([-0.08238091, -0.0679885 , -0.06328304, -0.06112487, -0.09421991,
#        -0.08668034, -0.07014499, -0.07718237, -0.06927648, -0.22887669])

# %%
x_vif=x.drop('Economy (GDP per Capita)',axis=1)

# %%
x_train,x_test,y_train,y_test=TTS(x_vif,y,test_size=0.1,random_state=102)

best_reg=best_model.fit(x_train,y_train)
y_pred=best_reg.predict(x_test)

plt.scatter(x=y_test.index,y=y_test,cmap='red')
plt.scatter(x=y_test.index,y=y_pred,cmap='blue')


scores = cross_val_score(model4, x, y, scoring='neg_root_mean_squared_error',
                         cv=10, n_jobs=-1)

print(scores.mean())
print(scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# -0.08940303205994496
# [-0.08173633 -0.06398924 -0.05996979 -0.06171119 -0.09144384 -0.08996973
#  -0.06832317 -0.08088125 -0.06772548 -0.2282803 ]

# %% [markdown]
# After droping Economy (GDP per Capita) score has increased by a small amount
